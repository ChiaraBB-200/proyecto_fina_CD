# %%
import pandas as pd 
import plotly.express as px
import plotly.graph_objects as go
import warnings
warnings.filterwarnings("ignore")

# %%
df_budget= pd.read_excel("CR EJEMPLO MOD.xlsm" , sheet_name='Cost Report')
df_budget
# Out:
#       Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4      Unnamed: 5  \
# 0            NaN        NaN        NaN        NaN        NaN             NaN
# 1            NaN        NaN        NaN        NaN        NaN     COST REPORT
# 2            NaN        NaN        NaN        NaN        NaN      PRODUCTION
# 3            NaN        NaN        NaN        NaN        NaN            POST
# 4            NaN        NaN        NaN        NaN        NaN  Figures in MXN
# ...          ...        ...        ...        ...        ...             ...
# 2487         NaN        NaN        NaN        NaN        NaN             NaN
# 2488         NaN        NaN        NaN        NaN        NaN             NaN
# 2489         NaN        NaN        NaN        NaN        NaN             NaN
# 2490         NaN        NaN        NaN        NaN        NaN             NaN
# 2491         NaN        NaN        NaN        NaN        NaN             NaN
#
# ...
